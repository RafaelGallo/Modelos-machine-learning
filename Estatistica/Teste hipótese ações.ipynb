# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("PETR4.SA.csv")
dados
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2008-01-07  40.730000  40.849998  39.310001  39.505001  31.346725
# 1     2008-01-08  40.150002  42.305000  40.125000  41.674999  33.068596
# 2     2008-01-09  41.549999  42.459999  41.125000  42.459999  33.691483
# 3     2008-01-10  42.490002  42.735001  41.180000  42.049999  33.366150
# 4     2008-01-11  41.605000  42.139999  40.779999  40.779999  32.358414
# ...          ...        ...        ...        ...        ...        ...
# 3100  2020-07-06  22.389999  22.860001  22.309999  22.510000  22.510000
# 3101  2020-07-07  22.340000  22.469999  22.139999  22.230000  22.230000
# 3102  2020-07-08  22.450001  22.760000  22.400000  22.650000  22.650000
# 3103  2020-07-09  22.780001  22.809999  22.059999  22.139999  22.139999
# 3104  2020-07-10  22.190001  22.650000  22.059999  22.510000  22.510000
#
#           Volume
# 0     20632600.0
# 1     21824200.0
# 2     24218400.0
# 3     23222200.0
# ...

# %%
dados.columns = ["Data", "Aberta", "Alta", "Baixa", "Fechada", "Adj_fechada", "Volume"]
dados
# Out:
#             Data     Aberta       Alta      Baixa    Fechada  Adj_fechada  \
# 0     2008-01-07  40.730000  40.849998  39.310001  39.505001    31.346725
# 1     2008-01-08  40.150002  42.305000  40.125000  41.674999    33.068596
# 2     2008-01-09  41.549999  42.459999  41.125000  42.459999    33.691483
# 3     2008-01-10  42.490002  42.735001  41.180000  42.049999    33.366150
# 4     2008-01-11  41.605000  42.139999  40.779999  40.779999    32.358414
# ...          ...        ...        ...        ...        ...          ...
# 3100  2020-07-06  22.389999  22.860001  22.309999  22.510000    22.510000
# 3101  2020-07-07  22.340000  22.469999  22.139999  22.230000    22.230000
# 3102  2020-07-08  22.450001  22.760000  22.400000  22.650000    22.650000
# 3103  2020-07-09  22.780001  22.809999  22.059999  22.139999    22.139999
# 3104  2020-07-10  22.190001  22.650000  22.059999  22.510000    22.510000
#
#           Volume
# 0     20632600.0
# 1     21824200.0
# 2     24218400.0
# ...

# %%
dados.dtypes
# Out:
# Data            object
# Aberta         float64
# Alta           float64
# Baixa          float64
# Fechada        float64
# Adj fechada    float64
# Volume         float64
# dtype: object

# %%
print("Quantidade de linhas e colunas:", dados.shape)
# Out:
# Quantidade de linhas e colunas: (3105, 7)

# %%
print("Dados nulos", dados.isna().sum())
# Out:
# Dados nulos Data            0
# Aberta         44
# Alta           44
# Baixa          44
# Fechada        44
# Adj fechada    44
# Volume         44
# dtype: int64

# %%
print("A base de dados contem {} registros".format(dados.shape[0]))
# Out:
# A base de dados contem 3105 registros

# %%
print("A base de dados contém {} registros \n".format(dados.shape[0]))

print("Registros não nulos")
dados.count()
# Out:
# A base de dados contém 3105 registros
#
# Registros não nulos
# Data           3105
# Aberta         3061
# Alta           3061
# Baixa          3061
# Fechada        3061
# Adj fechada    3061
# Volume         3061
# dtype: int64

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Aberta"])

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Alta"])

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Baixa"])

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Fechada"])

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Adj_fechada"])

# %%
plt.figure(figsize=(20, 10))

plt.plot(dados["Volume"])

# %%
dados["Aberta"].hist(bins = 20)

# %% [markdown]
# **Teste de hipótese**

# %%
from scipy.stats import normaltest

# %%
significancia = 0.05

# %%
stat_test, p_valor = normaltest(dados.Alta)
print(stat_test)
print(p_valor)

p_valor <= significancia
# Out:
# nan
# nan
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\stats.py:1548: RuntimeWarning: invalid value encountered in sign
#   term2 = np.sign(denom) * np.where(denom == 0.0, np.nan,
# False

# %%
stat_test, p_valor = normaltest(dados.Alta)
print(stat_test)
print(p_valor)

p_valor <= significancia
# Out:
# nan
# nan
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\RafaelHenriqueGallo\Anaconda\lib\site-packages\scipy\stats\stats.py:1548: RuntimeWarning: invalid value encountered in sign
#   term2 = np.sign(denom) * np.where(denom == 0.0, np.nan,
# False
