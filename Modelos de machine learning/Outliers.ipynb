# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("credit_data.csv")
dados.head()
# Out:
#    i#clientid        income        age         loan  c#default
# 0           1  66155.925095  59.017015  8106.532131          0
# 1           2  34415.153966  48.117153  6564.745018          0
# 2           3  57317.170063  63.108049  8020.953296          0
# 3           4  42709.534201  45.751972  6103.642260          0
# 4           5  66952.688845  18.584336  8770.099235          1

# %%
dados = dados.dropna()
dados
# Out:
#       i#clientid        income        age         loan  c#default
# 0              1  66155.925095  59.017015  8106.532131          0
# 1              2  34415.153966  48.117153  6564.745018          0
# 2              3  57317.170063  63.108049  8020.953296          0
# 3              4  42709.534201  45.751972  6103.642260          0
# 4              5  66952.688845  18.584336  8770.099235          1
# ...          ...           ...        ...          ...        ...
# 1995        1996  59221.044874  48.518179  1926.729397          0
# 1996        1997  69516.127573  23.162104  3503.176156          0
# 1997        1998  44311.449262  28.017167  5522.786693          1
# 1998        1999  43756.056605  63.971796  1622.722598          0
# 1999        2000  69436.579552  56.152617  7378.833599          0
#
# [1997 rows x 5 columns]

# %%
plt.figure(figsize=(10, 8))

plt.boxplot(dados.iloc[:, 2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149e9e28648>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149e9e28f88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ea5c4688>],
#  'medians': [<matplotlib.lines.Line2D at 0x149e9e30848>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149e9e30948>],
#  'means': []}

# %%
plt.figure(figsize=(10, 8))

plt.boxplot(dados.iloc[:, 3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149e9faad08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149e9fafc88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149e9faa2c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x149e9fb4c08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149e9fb4d08>],
#  'means': []}

# %%
#Fraude

outliers = dados[(dados.loan <- -150)]
outliers
# Out:
#       i#clientid        income        age        loan  c#default
# 5              6  24904.064140  57.471607   15.498598          0
# 66            67  37521.017173  60.541077    8.012076          0
# 105          106  47634.549548  44.294871  141.703818          0
# 111          112  41631.666296  53.047655  106.090747          0
# 117          118  63062.142096  26.585778   56.166164          0
# 187          188  35032.649599  56.724626  135.931684          0
# 304          305  51589.282746  50.313465   56.990974          0
# 320          321  36132.423875  34.294260   99.449591          0
# 431          432  30594.176559  50.043820  118.342142          0
# 465          466  63806.329253  56.632166  114.499967          0
# 560          561  40053.722267  27.938480   44.527246          0
# 667          668  63914.225372  26.349742  139.314572          0
# 733          734  22581.133973  40.548862   34.285106          0
# ...

# %%
#Outliers age

plt.figure(figsize=(10, 6))
plt.boxplot(dados.iloc[:, 2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x149ea48f788>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x149ea495748>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x149ea48acc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x149ea495fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x149ea499e48>],
#  'means': []}

# %%
dados_outliers_loan = dados[(dados.income > 13400)]
dados_outliers_loan
# Out:
#       i#clientid        income        age         loan  c#default
# 0              1  66155.925095  59.017015  8106.532131          0
# 1              2  34415.153966  48.117153  6564.745018          0
# 2              3  57317.170063  63.108049  8020.953296          0
# 3              4  42709.534201  45.751972  6103.642260          0
# 4              5  66952.688845  18.584336  8770.099235          1
# ...          ...           ...        ...          ...        ...
# 1995        1996  59221.044874  48.518179  1926.729397          0
# 1996        1997  69516.127573  23.162104  3503.176156          0
# 1997        1998  44311.449262  28.017167  5522.786693          1
# 1998        1999  43756.056605  63.971796  1622.722598          0
# 1999        2000  69436.579552  56.152617  7378.833599          0
#
# [1997 rows x 5 columns]

# %%
plt.scatter(dados.iloc[:, 2], dados.iloc[:, 3])

# %%
plt.scatter(dados.iloc[:, 1], dados.iloc[:, 3])
