# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelGallo/Projetos-machine-learning/blob/master/Series_temporais_ARIMA_SARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.tsa.api as smtsa
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')

# %%
df = pd.read_csv("Fish.csv")
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
print("Quantidade de linhas e colunas:", df.shape)
# Out:
# Quantidade de linhas e colunas: (159, 7)

# %%
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 0

# %%
df.columns = ["Especie", "Peso", "Comprimento1", "Comprimento2", "Comprimento3", "Altura", "Largura"]

df.head()
# Out:
#   Especie   Peso  Comprimento1  Comprimento2  Comprimento3   Altura  Largura
# 0   Bream  242.0          23.2          25.4          30.0  11.5200   4.0200
# 1   Bream  290.0          24.0          26.3          31.2  12.4800   4.3056
# 2   Bream  340.0          23.9          26.5          31.1  12.3778   4.6961
# 3   Bream  363.0          26.3          29.0          33.5  12.7300   4.4555
# 4   Bream  430.0          26.5          29.0          34.0  12.4440   5.1340

# %%
sns.lineplot(x="Peso", y="Altura", data=df)

# %%
plt.figure(figsize=(16,12))

sns.lineplot(x="Altura", y="Largura", data=df)

# %%
plt.figure(figsize=(16,12))

sns.lineplot(x="Peso", y="Comprimento1", data=df)

# %%
plt.figure(figsize=(20, 10))
plt.style.use('seaborn-darkgrid')

x1 = sns.lineplot(x="Comprimento1", y="Peso", data=df)
plt.xticks(rotation=70);
plt.show()

# %%
plt.figure(figsize=(16,12))
ax = plt.subplot(3,1,1)

sns.lineplot(x='Comprimento1', y='Comprimento2', data=df)
plt.subplot(3,1,2)

sns.lineplot(x='Comprimento2', y='Comprimento3', data=df)
plt.subplot(3,1,3)

sns.lineplot(x='Peso', y='Altura', data=df)
ax = ax

# %%
from pandas.plotting import autocorrelation_plot

ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação dos Pesos', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df['Peso'])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação do aumento', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df['Altura'][1:])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação da aceleração', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df['Largura'][2:])
ax = ax

# %%
plt.figure(figsize=(16,12))
ax = plt.subplot(3,1,1)

sns.lineplot(x="Comprimento1", y="Peso", data=df)
plt.subplot(3,1,2)

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle("Correlação dos Pesos", fontsize=18, x=0.3, y=0.95)
autocorrelation_plot(df['Peso'])
ax = ax

# %% [markdown]
# **Modelo ARIMA, SARIMA**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(df["Peso"]);

# %%
plot_acf(df["Comprimento1"])

# %%
plot_pacf(df["Comprimento2"])

# %%
df_1 = df[:26][:]
df_2 = df[26:][:]

# %%
from pmdarima.arima import auto_arima
modelo_arima = auto_arima(df_1["Peso"].values, start_p = 0, start_q = 0,
                         max_p = 8, max_q = 8, d = 2, seasonal = False, trace = True,
                         error_action = "ignore", suppress_warnings = True, stepwise = False)
# Out:
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=309.744, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=288.859, Time=0.07 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=284.902, Time=0.13 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=286.052, Time=0.28 sec
#  ARIMA(0,2,4)(0,0,0)[0] intercept   : AIC=282.867, Time=0.30 sec
#  ARIMA(0,2,5)(0,0,0)[0] intercept   : AIC=283.454, Time=0.32 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=294.214, Time=0.04 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=285.376, Time=0.11 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=285.651, Time=0.23 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=288.183, Time=0.29 sec
#  ARIMA(1,2,4)(0,0,0)[0] intercept   : AIC=292.506, Time=0.38 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=291.825, Time=0.08 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=287.372, Time=0.10 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=288.528, Time=0.20 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=290.442, Time=0.28 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=293.771, Time=0.08 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=289.359, Time=0.24 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=290.463, Time=0.27 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=292.438, Time=0.10 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=287.566, Time=0.17 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=291.211, Time=0.13 sec
# Total fit time: 3.800 seconds

# %%
modelo_arima.aic()
# Out:
# 282.86698404688775

# %%
modelo_arima.fit(df_1["Peso"]. values)

model_predict = modelo_arima.predict(n_periods = 10)
model_predict
# Out:
# array([731.11663182, 742.21160405, 734.25281022, 741.66583605,
#        748.46279201, 754.6436781 , 760.20849432, 765.15724067,
#        769.48991716, 773.20652377])

# %%
plt.figure(figsize=(20, 10))

plt.plot(df["Peso"])
plt.plot(model_predict)

# %% [markdown]
# # **Modelo Sarima**

# %%
from pmdarima.arima.utils import nsdiffs

df_s = nsdiffs(df['Peso'].values, m=2, max_D=12, test='ch')
df_s
# Out:
# 0

# %%
from pmdarima.arima import auto_arima

modelo_sarima = auto_arima(df['Peso'].values,start_p = 0, start_q = 0, max_p = 6, max_q = 6, d = 1,D = 1,
                            start_Q = 2, start_P = 2, max_P = 5, max_Q = 5, m = 3, seasonal = True, trace = True, 
                            error_action ='ignore',
                            suppress_warnings = True, stepwise = False, maxiter = 50)

modelo_sarima.aic()
# Out:
#  ARIMA(0,1,0)(0,1,0)[3]             : AIC=2217.854, Time=0.02 sec
#  ARIMA(0,1,0)(0,1,1)[3]             : AIC=2102.143, Time=0.07 sec
#  ARIMA(0,1,0)(0,1,2)[3]             : AIC=2100.590, Time=0.21 sec
#  ARIMA(0,1,0)(0,1,3)[3]             : AIC=2101.329, Time=0.53 sec
#  ARIMA(0,1,0)(0,1,4)[3]             : AIC=2103.286, Time=0.56 sec
#  ARIMA(0,1,0)(0,1,5)[3]             : AIC=2105.051, Time=0.90 sec
#  ARIMA(0,1,0)(1,1,0)[3]             : AIC=2170.425, Time=0.03 sec
#  ARIMA(0,1,0)(1,1,1)[3]             : AIC=2101.267, Time=0.14 sec
#  ARIMA(0,1,0)(1,1,2)[3]             : AIC=2100.467, Time=0.62 sec
#  ARIMA(0,1,0)(1,1,3)[3]             : AIC=2103.286, Time=1.08 sec
#  ARIMA(0,1,0)(1,1,4)[3]             : AIC=2104.440, Time=1.41 sec
#  ARIMA(0,1,0)(2,1,0)[3]             : AIC=2147.443, Time=0.10 sec
#  ARIMA(0,1,0)(2,1,1)[3]             : AIC=2101.700, Time=0.27 sec
#  ARIMA(0,1,0)(2,1,2)[3]             : AIC=2102.031, Time=0.74 sec
#  ARIMA(0,1,0)(2,1,3)[3]             : AIC=2103.994, Time=1.16 sec
#  ARIMA(0,1,0)(3,1,0)[3]             : AIC=2138.138, Time=0.24 sec
#  ARIMA(0,1,0)(3,1,1)[3]             : AIC=2103.518, Time=0.54 sec
#  ARIMA(0,1,0)(3,1,2)[3]             : AIC=2103.878, Time=1.10 sec
#  ARIMA(0,1,0)(4,1,0)[3]             : AIC=2126.910, Time=0.27 sec
#  ARIMA(0,1,0)(4,1,1)[3]             : AIC=2105.126, Time=0.78 sec
#  ARIMA(0,1,0)(5,1,0)[3]             : AIC=2122.412, Time=0.45 sec
#  ARIMA(0,1,1)(0,1,0)[3]             : AIC=2219.610, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,1)[3]             : AIC=2103.381, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,2)[3]             : AIC=2101.540, Time=0.36 sec
#  ARIMA(0,1,1)(0,1,3)[3]             : AIC=2102.113, Time=1.05 sec
#  ARIMA(0,1,1)(0,1,4)[3]             : AIC=2104.033, Time=0.81 sec
#  ARIMA(0,1,1)(1,1,0)[3]             : AIC=2171.943, Time=0.12 sec
#  ARIMA(0,1,1)(1,1,1)[3]             : AIC=2102.310, Time=0.26 sec
#  ARIMA(0,1,1)(1,1,2)[3]             : AIC=2100.984, Time=1.10 sec
#  ARIMA(0,1,1)(1,1,3)[3]             : AIC=2102.370, Time=1.20 sec
#  ARIMA(0,1,1)(2,1,0)[3]             : AIC=2148.998, Time=0.14 sec
#  ARIMA(0,1,1)(2,1,1)[3]             : AIC=2102.611, Time=0.38 sec
#  ARIMA(0,1,1)(2,1,2)[3]             : AIC=2102.645, Time=1.25 sec
#  ARIMA(0,1,1)(3,1,0)[3]             : AIC=2139.682, Time=0.31 sec
#  ARIMA(0,1,1)(3,1,1)[3]             : AIC=2104.360, Time=0.62 sec
#  ARIMA(0,1,1)(4,1,0)[3]             : AIC=2128.539, Time=0.35 sec
#  ARIMA(0,1,2)(0,1,0)[3]             : AIC=2202.881, Time=0.23 sec
#  ARIMA(0,1,2)(0,1,1)[3]             : AIC=2105.192, Time=0.28 sec
#  ARIMA(0,1,2)(0,1,2)[3]             : AIC=2103.236, Time=0.61 sec
#  ARIMA(0,1,2)(0,1,3)[3]             : AIC=2103.984, Time=0.61 sec
#  ARIMA(0,1,2)(1,1,0)[3]             : AIC=2173.070, Time=0.15 sec
#  ARIMA(0,1,2)(1,1,1)[3]             : AIC=2103.999, Time=0.36 sec
#  ARIMA(0,1,2)(1,1,2)[3]             : AIC=2103.128, Time=1.28 sec
#  ARIMA(0,1,2)(2,1,0)[3]             : AIC=2150.460, Time=0.19 sec
#  ARIMA(0,1,2)(2,1,1)[3]             : AIC=2104.439, Time=0.45 sec
#  ARIMA(0,1,2)(3,1,0)[3]             : AIC=2140.921, Time=0.32 sec
#  ARIMA(1,1,0)(0,1,0)[3]             : AIC=2219.535, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[3]             : AIC=2103.323, Time=0.13 sec
#  ARIMA(1,1,0)(0,1,2)[3]             : AIC=2101.466, Time=0.29 sec
#  ARIMA(1,1,0)(0,1,3)[3]             : AIC=2102.059, Time=0.75 sec
#  ARIMA(1,1,0)(0,1,4)[3]             : AIC=2103.978, Time=0.78 sec
#  ARIMA(1,1,0)(1,1,0)[3]             : AIC=2171.876, Time=0.10 sec
#  ARIMA(1,1,0)(1,1,1)[3]             : AIC=2102.237, Time=0.25 sec
#  ARIMA(1,1,0)(1,1,2)[3]             : AIC=2100.933, Time=1.03 sec
#  ARIMA(1,1,0)(1,1,3)[3]             : AIC=2102.784, Time=1.25 sec
#  ARIMA(1,1,0)(2,1,0)[3]             : AIC=2148.946, Time=0.15 sec
#  ARIMA(1,1,0)(2,1,1)[3]             : AIC=2102.553, Time=0.47 sec
#  ARIMA(1,1,0)(2,1,2)[3]             : AIC=2102.671, Time=1.22 sec
#  ARIMA(1,1,0)(3,1,0)[3]             : AIC=2139.623, Time=0.29 sec
#  ARIMA(1,1,0)(3,1,1)[3]             : AIC=2104.301, Time=0.66 sec
#  ARIMA(1,1,0)(4,1,0)[3]             : AIC=2128.526, Time=0.45 sec
#  ARIMA(1,1,1)(0,1,0)[3]             : AIC=2221.853, Time=0.08 sec
#  ARIMA(1,1,1)(0,1,1)[3]             : AIC=2106.136, Time=0.23 sec
#  ARIMA(1,1,1)(0,1,2)[3]             : AIC=2104.090, Time=0.70 sec
#  ARIMA(1,1,1)(0,1,3)[3]             : AIC=2105.398, Time=1.05 sec
#  ARIMA(1,1,1)(1,1,0)[3]             : AIC=2172.687, Time=0.16 sec
#  ARIMA(1,1,1)(1,1,1)[3]             : AIC=2105.270, Time=0.32 sec
#  ARIMA(1,1,1)(1,1,2)[3]             : AIC=3370.638, Time=0.87 sec
#  ARIMA(1,1,1)(2,1,0)[3]             : AIC=2151.442, Time=0.58 sec
#  ARIMA(1,1,1)(2,1,1)[3]             : AIC=2105.702, Time=0.50 sec
#  ARIMA(1,1,1)(3,1,0)[3]             : AIC=2142.138, Time=0.91 sec
#  ARIMA(1,1,2)(0,1,0)[3]             : AIC=2161.621, Time=0.33 sec
#  ARIMA(1,1,2)(0,1,1)[3]             : AIC=2107.383, Time=0.48 sec
#  ARIMA(1,1,2)(0,1,2)[3]             : AIC=2105.559, Time=0.84 sec
#  ARIMA(1,1,2)(1,1,0)[3]             : AIC=2160.488, Time=0.59 sec
#  ARIMA(1,1,2)(1,1,1)[3]             : AIC=2104.807, Time=0.77 sec
#  ARIMA(1,1,2)(2,1,0)[3]             : AIC=2151.727, Time=0.50 sec
#  ARIMA(2,1,0)(0,1,0)[3]             : AIC=2220.828, Time=0.02 sec
#  ARIMA(2,1,0)(0,1,1)[3]             : AIC=2105.017, Time=0.21 sec
#  ARIMA(2,1,0)(0,1,2)[3]             : AIC=2103.322, Time=0.41 sec
#  ARIMA(2,1,0)(0,1,3)[3]             : AIC=2104.010, Time=0.97 sec
#  ARIMA(2,1,0)(1,1,0)[3]             : AIC=2172.818, Time=0.14 sec
#  ARIMA(2,1,0)(1,1,1)[3]             : AIC=2104.032, Time=0.37 sec
#  ARIMA(2,1,0)(1,1,2)[3]             : AIC=2102.863, Time=1.31 sec
#  ARIMA(2,1,0)(2,1,0)[3]             : AIC=2150.361, Time=0.18 sec
#  ARIMA(2,1,0)(2,1,1)[3]             : AIC=2104.466, Time=0.52 sec
#  ARIMA(2,1,0)(3,1,0)[3]             : AIC=2140.914, Time=0.40 sec
#  ARIMA(2,1,1)(0,1,0)[3]             : AIC=2213.426, Time=0.17 sec
#  ARIMA(2,1,1)(0,1,1)[3]             : AIC=2107.313, Time=0.59 sec
#  ARIMA(2,1,1)(0,1,2)[3]             : AIC=2105.469, Time=0.66 sec
#  ARIMA(2,1,1)(1,1,0)[3]             : AIC=2173.513, Time=0.28 sec
#  ARIMA(2,1,1)(1,1,1)[3]             : AIC=2104.552, Time=0.64 sec
#  ARIMA(2,1,1)(2,1,0)[3]             : AIC=2152.024, Time=0.47 sec
#  ARIMA(2,1,2)(0,1,0)[3]             : AIC=2192.097, Time=0.39 sec
#  ARIMA(2,1,2)(0,1,1)[3]             : AIC=2110.575, Time=0.96 sec
#  ARIMA(2,1,2)(1,1,0)[3]             : AIC=2136.887, Time=0.61 sec
# Total fit time: 49.932 seconds
# 2100.467080422057

# %%
modelo_sarima.fit(df_1["Peso"]. values)

ml_predict = modelo_sarima.predict(n_periods = 10)
ml_predict
# Out:
# array([770.91797134, 786.50183547, 772.38422467, 826.24746603,
#        851.43997406, 846.43288412, 892.71531256, 908.73993433,
#        895.04023179, 948.55573405])

# %%
plt.plot(ml_predict)

plt.plot(df["Comprimento1"], df["Comprimento2"])
