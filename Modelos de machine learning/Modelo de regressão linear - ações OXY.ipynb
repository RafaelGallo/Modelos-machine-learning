# %% [markdown]
# # Modelo de regressão linear ações OXY - Occidental Petroleum.

# %% [markdown]
# **Previsão com as melhores ações para comprar usando modelo de regressão linear.**
#
# **Algoritmos** Floresta randômica.
#
# **Regressão linear**: RMSE, MAE, MSE.
#
# **Analise exploratória de dados**:
# Analise das ações com graficos boxplot

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("Dados\OXY.csv")
dados.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2015-06-29  77.887367  77.977211  76.968933  77.238472  60.168545  4901900
# 1  2015-06-30  78.047096  78.146927  77.258438  77.637794  60.479614  4082100
# 2  2015-07-01  77.398201  77.627808  75.441528  75.820885  59.064232  4249900
# 3  2015-07-02  76.280106  76.759285  75.581291  75.601257  58.893158  3012500
# 4  2015-07-06  74.393318  74.563026  73.574707  73.774368  57.470016  4224500

# %%
dados.shape
# Out:
# (1259, 7)

# %%
dados.columns = ["Data", "Aberta", "Alta", "Baixa", "Fechada", "Adj Fechar", "Volume"]
dados.head()
# Out:
#          Data     Aberta       Alta      Baixa    Fechada  Adj Fechar   Volume
# 0  2015-06-29  77.887367  77.977211  76.968933  77.238472   60.168545  4901900
# 1  2015-06-30  78.047096  78.146927  77.258438  77.637794   60.479614  4082100
# 2  2015-07-01  77.398201  77.627808  75.441528  75.820885   59.064232  4249900
# 3  2015-07-02  76.280106  76.759285  75.581291  75.601257   58.893158  3012500
# 4  2015-07-06  74.393318  74.563026  73.574707  73.774368   57.470016  4224500

# %%
dados.tail()
# Out:
#             Data     Aberta       Alta      Baixa    Fechada  Adj Fechar  \
# 1254  2020-06-22  19.850000  20.110001  19.389999  19.910000   19.910000
# 1255  2020-06-23  20.260000  20.520000  19.629999  19.790001   19.790001
# 1256  2020-06-24  19.240000  19.320000  17.670000  18.000000   18.000000
# 1257  2020-06-25  17.799999  18.900000  17.549999  18.540001   18.540001
# 1258  2020-06-26  18.200001  18.350000  17.350000  17.690001   17.690001
#
#         Volume
# 1254  30116700
# 1255  33856800
# 1256  32322000
# 1257  23327600
# 1258  31801000

# %% [markdown]
# # Estátistica

# %%
dados.describe()
# Out:
#             Aberta         Alta        Baixa      Fechada   Adj Fechar  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     62.393127    63.042778    61.658275    62.353236    53.624209
# std      16.656955    16.677200    16.660069    16.683588    13.263346
# min      10.230000    10.290000     9.000000     9.690000     9.684434
# 25%      59.515000    60.035002    58.885001    59.584999    50.408231
# 50%      66.959999    67.699997    66.120003    66.900002    56.134335
# 75%      73.387501    74.048904    72.453301    73.349998    60.700352
# max      87.000000    87.669998    86.169998    86.480003    76.552582
#
#              Volume
# count  1.259000e+03
# mean   8.589645e+06
# std    1.241577e+07
# min    1.319200e+06
# 25%    3.831950e+06
# 50%    5.027900e+06
# 75%    7.392000e+06
# max    1.312858e+08

# %% [markdown]
# **Média**

# %%
print("Media da ação alta:",dados["Alta"].mean())
# Out:
# Media da ação alta: 63.04277750277986

# %%
print("Media da ação baixa:", dados["Baixa"].mean())
# Out:
# Media da ação baixa: 61.658274716441625

# %%
print("Media da ação fechada:", dados["Fechada"].mean())
# Out:
# Media da ação fechada: 62.353236411437614

# %% [markdown]
# **Moda**

# %%
print("Moda da ação alta", dados["Alta"].mode())
# Out:
# Moda da ação alta 0    62.119999
# dtype: float64

# %%
print("Moda da ação baixa", dados["Baixa"].mode())
# Out:
# Moda da ação baixa 0    59.669998
# dtype: float64

# %%
print("Moda da ação fechada", dados["Fechada"].mode())
# Out:
# Moda da ação fechada 0     40.500000
# 1     42.119999
# 2     60.119999
# 3     61.860001
# 4     63.360001
# 5     63.910000
# 6     64.959999
# 7     65.059998
# 8     65.470001
# 9     66.629997
# 10    67.180000
# 11    68.190002
# 12    69.320000
# 13    73.120003
# 14    73.540001
# 15    74.250000
# 16    75.440002
# 17    75.449997
# 18    76.529999
# 19    83.860001
# dtype: float64

# %% [markdown]
# **Médiana**

# %%
print("Mediana da ação alta", dados["Alta"].median())
# Out:
# Mediana da ação alta 67.699997

# %%
print("Mediana da ação baixa:", dados["Baixa"].median())
# Out:
# Mediana da ação baixa: 66.120003

# %%
print("Mediana da ação fechada:",dados["Fechada"].median())
# Out:
# Mediana da ação fechada: 66.900002

# %% [markdown]
# # Graficos boxplot

# %%
df = plt.figure(figsize=(8, 6))

sns.boxplot(dados.Aberta)

# %%
df = plt.figure(figsize=(8, 6))

sns.boxplot(dados.Alta)

# %%
df = plt.figure(figsize=(8, 6))

sns.boxplot(dados.Baixa)

# %%
df = plt.figure(figsize=(8, 6))

sns.boxplot(dados.Fechada)

# %% [markdown]
# # Análise descritiva

# %%
#Media

media_geral_ações = dados.Alta.mean()
print("A média geral é de {}". format(media_geral_ações))
# Out:
# A média geral é de 63.04277750277986

# %%
#Mediana

media_geral_ações = dados.Alta.median()
print("A Mediana geral é de {}". format(media_geral_ações))
# Out:
# A Mediana geral é de 67.699997

# %%
#Moda

media_geral_ações = dados.Alta.mode()
print("A moda geral é de {}". format(media_geral_ações))
# Out:
# A moda geral é de 0    62.119999
# dtype: float64

# %%
dados.groupby(["Aberta"]).mean()
# Out:
#                 Alta      Baixa    Fechada  Adj Fechar      Volume
# Aberta
# 10.230000  14.840000   9.440000  11.890000   11.883171  73141800.0
# 10.250000  10.290000   9.470000   9.690000    9.684434  36784000.0
# 10.400000  10.770000   9.700000  10.720000   10.713842  42020600.0
# 10.410000  10.980000   9.400000  10.830000   10.823779  38092500.0
# 10.450000  10.840000   9.000000  10.530000   10.523952  41257200.0
# ...              ...        ...        ...         ...         ...
# 85.910004  87.120003  85.839996  86.459999   76.143974   6534300.0
# 85.980003  86.320000  85.220001  85.790001   75.553932   5806100.0
# 85.989998  86.099998  84.989998  85.419998   75.228073   3498600.0
# 86.010002  86.279999  84.660004  85.470001   75.948341   5533200.0
# 87.000000  87.669998  86.169998  86.480003   76.161606   7229000.0
#
# [1105 rows x 5 columns]

# %%
dados.groupby(["Alta"]).mean()
# Out:
#               Aberta      Baixa    Fechada  Adj Fechar      Volume
# Alta
# 10.290000  10.250000   9.470000   9.690000    9.684434  36784000.0
# 10.770000  10.400000   9.700000  10.720000   10.713842  42020600.0
# 10.840000  10.450000   9.000000  10.530000   10.523952  41257200.0
# 10.980000  10.410000   9.400000  10.830000   10.823779  38092500.0
# 11.170000  11.040000  10.120000  10.740000   10.733830  39837200.0
# ...              ...        ...        ...         ...         ...
# 86.599998  85.620003  85.529999  85.699997   76.152710   4601500.0
# 86.760002  85.889999  85.290001  86.150002   76.552582   5813400.0
# 87.120003  85.910004  85.839996  86.459999   76.143974   6534300.0
# 87.169998  85.650002  85.290001  85.510002   75.307335   6391000.0
# 87.669998  87.000000  86.169998  86.480003   76.161606   7229000.0
#
# [1110 rows x 5 columns]

# %%
dados.groupby(["Baixa"]).mean()
# Out:
#               Aberta       Alta    Fechada  Adj Fechar      Volume
# Baixa
# 9.000000   10.450000  10.840000  10.530000   10.523952  41257200.0
# 9.400000   10.410000  10.980000  10.830000   10.823779  38092500.0
# 9.440000   10.230000  14.840000  11.890000   11.883171  73141800.0
# 9.470000   10.250000  10.290000   9.690000    9.684434  36784000.0
# 9.550000   11.150000  11.180000  10.230000   10.224123  50833300.0
# ...              ...        ...        ...         ...         ...
# 85.220001  85.980003  86.320000  85.790001   75.553932   5806100.0
# 85.290001  85.770001  86.965000  85.830002   75.929958   6102200.0
# 85.529999  85.620003  86.599998  85.699997   76.152710   4601500.0
# 85.839996  85.910004  87.120003  86.459999   76.143974   6534300.0
# 86.169998  87.000000  87.669998  86.480003   76.161606   7229000.0
#
# [1119 rows x 5 columns]

# %% [markdown]
# # Analise exploratória de dados

# %%
df = plt.figure(figsize=(8, 6))
sns.barplot(x='Alta', y='Baixa', data=dados)

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Aberta"])

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Alta"])

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Baixa"])

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Fechada"])

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Aberta"], kde=False)

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Alta"], kde=False)

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Baixa"], kde=False)

# %%
df = plt.figure(figsize=(8, 6))

sns.distplot(dados["Fechada"], kde=False)

# %%
df = plt.figure(figsize=(8, 6))

sns.countplot(x='Alta', data=dados)

# %%
df = plt.figure(figsize=(8, 6))

sns.countplot(x='Baixa', data=dados)

# %%
df = plt.figure(figsize=(8, 6))

sns.countplot(x="Fechada", data=dados)

# %%
sns.pairplot(dados)

# %%
#Regressão linear
df = plt.figure(figsize=(8, 6))

f1 = sns.lmplot(x="Alta", y="Baixa", data=dados)

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split

x = dados[["Aberta", "Alta", "Baixa", "Fechada", "Adj Fechar"]]
y = dados["Volume"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train
# Out:
#          Aberta       Alta      Baixa    Fechada  Adj Fechar
# 824   81.910004  82.629997  81.500000  82.180000   73.766617
# 200   72.660004  74.470001  72.300003  74.320000   59.805180
# 80    72.366768  72.855934  71.817703  71.887581   56.610851
# 668   67.820000  68.809998  67.360001  67.919998   59.109562
# 806   77.000000  77.779999  76.839996  76.879997   69.009209
# ...         ...        ...        ...        ...         ...
# 639   74.900002  74.949997  74.139999  74.250000   64.618462
# 1121  37.509998  38.049999  37.250000  37.570000   36.444054
# 571   64.099998  64.139999  63.610001  63.980000   55.062962
# 397   68.099998  69.250000  67.910004  68.129997   56.519077
# 334   74.720001  75.400002  73.900002  75.029999   61.571327
#
# [881 rows x 5 columns]

# %%
x_test
# Out:
#          Aberta       Alta      Baixa    Fechada  Adj Fechar
# 899   64.540001  65.160004  64.010002  64.980003   59.009193
# 669   68.339996  68.849998  67.720001  68.320000   59.457687
# 556   60.349998  60.980000  60.279999  60.779999   52.308952
# 236   75.559998  76.180000  75.220001  75.410004   60.682320
# 322   72.739998  74.000000  72.599998  73.540001   60.348595
# ...         ...        ...        ...        ...         ...
# 400   68.529999  68.849998  67.320000  67.879997   56.311691
# 832   73.889999  73.970001  72.150002  73.120003   65.634155
# 1061  47.610001  48.849998  47.380001  47.799999   45.428467
# 637   74.599998  75.239998  74.410004  75.190002   65.436516
# 374   72.570000  72.870003  71.989998  72.379997   60.044796
#
# [378 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([['2015-06-29', 77.887367, 77.977211, 76.96893299999999],
#        ['2015-06-30', 78.047096, 78.146927, 77.258438],
#        ['2015-07-01', 77.398201, 77.627808, 75.441528],
#        ...,
#        ['2020-06-24', 19.24, 19.32, 17.67],
#        ['2020-06-25', 17.799999, 18.9, 17.549999],
#        ['2020-06-26', 18.200001, 18.35, 17.35]], dtype=object)

# %%
x_test
# Out:
# array([[ 0.14086684,  0.13890895,  0.15322626,  0.16975433,  0.42012903],
#        [ 0.36797   ,  0.35950264,  0.37492773,  0.36917014,  0.45381643],
#        [-0.10954479, -0.11097832, -0.0696706 , -0.08100853, -0.0831413 ],
#        ...,
#        [-0.87093883, -0.83612907, -0.8405464 , -0.85598444, -0.59995016],
#        [ 0.74209318,  0.74150697,  0.77470775,  0.77934626,  0.90289986],
#        [ 0.62077224,  0.59982491,  0.63009346,  0.61157383,  0.49791552]])

# %%
from sklearn.ensemble import RandomForestClassifier

x1 = RandomForestClassifier(n_estimators=100)
x1.fit(x_train, y_train)
x2 = x1.predict(x_test)
x2
# Out:
# array([  5489500,   2527700,   2806500,   2411400,   3117600,   5241400,
#         10508900,   4958800,   4153300,   4239100,   5855500,   4761900,
#          5284600,   5873700,   4946800,  34675600,   5673700,  41257200,
#          5305100,   4094300,   1682700,   3204400,   7461100,   5064300,
#          3355800,   3836700,   5358000,   4968800,   3050400,   4122700,
#          6184200,   4191900,   3687500,   3619900,   7662900,   2844200,
#          4844000,   5113000,   5822600,   7476900,   3672100,  34675600,
#          5427000,   2387800,   4271100,   3233700,   8480700,   3399500,
#          3082200,   4163200,   3864600,   5284600,   9850700,   5109400,
#          9308900,   4191900,   6594200,   1417700,   5489500,   4164700,
#          5200400,   2992200,   3212700,   3689900,   5701600,  16035700,
#         32064000,   3619900,   1682700,   5170200,   7127000,   3117400,
#          4158200,   4130300,   3659300,   7385600,   4696300,   4940200,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

x2 = RandomForestRegressor(n_estimators=20, random_state=0)
x2.fit(x_train, y_train)
x3 = regressor.predict(x_test)
x3
# Out:
# array([41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
#        41300280., 41300280., 41300280., 41300280., 41300280., 41300280.,
# ...

# %% [markdown]
# # **Modelo de regressão linear**

# %%
x = dados["Alta"]
y = dados["Baixa"]

# %%
plt.scatter(x,y)

# %%
treino, teste, treino_alta, teste_baixo = train_test_split(x, y)

# %%
x = np.array(x).reshape(len(x), 1)
x
# Out:
# array([[77.977211],
#        [78.146927],
#        [77.627808],
#        ...,
#        [19.32    ],
#        [18.9     ],
#        [18.35    ]])

# %%
y = np.array(y).reshape(len(y), 1)
y
# Out:
# array([[76.968933],
#        [77.258438],
#        [75.441528],
#        ...,
#        [17.67    ],
#        [17.549999],
#        [17.35    ]])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

regressor.fit(x, y)
modelo = LinearRegression()
modelo.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
modelo.intercept_
# Out:
# array([-1.26173547])

# %%
modelo.coef_
# Out:
# array([[0.99805263]])

# %%
modelo.coef_ * 32.74456356 + modelo.intercept_
# Out:
# array([[31.41906246]])

# %%
modelo_1 = LinearRegression()
modelo_1.fit(x, y)

modelo_1.score(x, y)
# Out:
# 0.9981586761973589

# %%
fig = plt.figure(figsize=(15, 9))

plt.scatter(x, y)
plt.plot(x, regressor.predict(x), color = "red")
plt.title("Regressão linear Ações da OXY - Occidental Petroleum", fontsize= 25)
plt.xlabel("Ações Alta", fontsize= 20)
plt.ylabel("Ações Baixa", fontsize= 20)
# Out:
# Text(0, 0.5, 'Ações Baixa')

# %% [markdown]
# # RMSE, MSE, MAE

# %% [markdown]
# **RMSE**

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = np.sqrt(mean_squared_error(x, y))
print("Erro quadrático média da raiz:", rmse)
# Out:
# Erro quadrático média da raiz: 1.558386940895405

# %% [markdown]
# **MAE**

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(x, y)
print("Erro médio absoluto:", mae)
# Out:
# Erro médio absoluto: 1.384502786338364

# %% [markdown]
# **MSE**

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(x, y)
print("Erro médio quadrático:", mse)
# Out:
# Erro médio quadrático: 2.428569857553338

# %% [markdown]
# # **Previssãoes das ações**

# %%
from sklearn.linear_model import LinearRegression


pre1 = regressor.predict(x)
pre2 = regressor.predict(y)

# %%
pre1
# Out:
# array([[76.56362542],
#        [76.73301092],
#        [76.21490283],
#        ...,
#        [18.02064143],
#        [17.60145932],
#        [17.05253037]])

# %%
pre2
# Out:
# array([[75.5573109 ],
#        [75.84625213],
#        [74.03288032],
#        ...,
#        [16.37385458],
#        [16.25408727],
#        [16.05447774]])

# %%
plt.plot(pre1, markersize = 100, label = 'Ação - 1')
plt.plot(pre1, label = 'Ação - 2')
plt.legend()

# %%
plt.plot(pre2, label = 'Ação - 1')
plt.plot(pre2, markersize = 10, color = 'red')
plt.plot(pre2, label = 'Ação - 2')
plt.legend()
